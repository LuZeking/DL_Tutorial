# %% [markdown]
# # Modeling Procedure
#
# In principle, the neural network could be defined by graphs consist of tensors and trained through automatic differenciate.
#
# However, for simplification, we recommend to use high-level Keras API in Tensorflow to implement the neural networks.
#
# The common procedures of implementing neural networks using TensorFlow are:
#
# 1. Data preparation and loading
# 2. Model definition
# 3. Model training
# 4. Model evaluation, application and saving

# %%
import sys
import os
project_path = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_path)
import numpy as np
import pandas as pd
import datetime
import re,string

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models,layers
from tensorflow.keras import models,layers,losses,metrics,callbacks 

from utils.dataset_loader import load_cifar10,get_temporal_sequences_dataset,get_txt_dataset_from_csv,structured_data_preprocessing,get_dataset_from_list_files
from utils.trainer import plot_metric
from backbone.cnn import CNN_3L, Sequential_CNN_3L

# %%
# 1 Dataset and dataloader
df = pd.read_csv("../../data/covid-19.csv",sep = "\t")
ds_train, dfdiff= get_temporal_sequences_dataset(df,WINDOW_SIZE = 8)
for x,y in ds_train.take(1): # ds_train = (x_train , y_train)
    print(x.shape,y.shape)

# 2 Model definition (Sequential, Model(Input,Output))
tf.keras.backend.clear_session()
#We design the following block since the daily increment of confirmed, discharged and deceased cases are equal or larger than zero.
class Block(layers.Layer):
    def __init__(self, **kwargs):
        super(Block, self).__init__(**kwargs)
    
    def call(self, x_input,x):
        x_out = tf.maximum((1+x)*x_input[:,-1,:],0.0)
        return x_out
    
    def get_config(self):  
        config = super(Block, self).get_config()
        return config

tf.keras.backend.clear_session()
x_input = layers.Input(shape = (None,3),dtype = tf.float32)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x_input)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x)
x = layers.LSTM(3,return_sequences = True,input_shape=(None,3))(x)
x = layers.LSTM(3,input_shape=(None,3))(x)
x = layers.Dense(3)(x)

#We design the following block since the daily increment of confirmed, discharged and deseased cases are equal or larger than zero.
#x = tf.maximum((1+x)*x_input[:,-1,:],0.0)
x = Block()(x_input,x)
model = models.Model(inputs = [x_input],outputs = [x])

# 3 Set optimizer and training
#Customized loss function, consider the ratio between square error and the prediction
class MSPE(losses.Loss):
    def call(self,y_true,y_pred):
        err_percent = (y_true - y_pred)**2/(tf.maximum(y_true**2,1e-7))
        mean_err_percent = tf.reduce_mean(err_percent)
        return mean_err_percent
    
    def get_config(self):
        config = super(MSPE, self).get_config()
        return config

model.compile(optimizer="adam", loss=MSPE(name = "MSPE"))  # no metric ?

stamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
logdir = os.path.join('data', 'autograph', stamp)
tb_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
#Half the learning rate if loss is not improved after 100 epoches
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor = 0.5, patience = 100)
#Stop training when loss is not improved after 200 epoches
stop_callback = tf.keras.callbacks.EarlyStopping(monitor = "loss", patience= 200)
callbacks_list = [tb_callback,lr_callback,stop_callback]

history = model.fit(ds_train, epochs=500, # no ds_test 
                    callbacks = callbacks_list)   # no ,workers = 4
model.summary()

# 4 Model evaluation, application and saving
# Out:
# (38, 8, 3) (38, 3)
# Epoch 1/300
# 1/1 [==============================] - 0s 29ms/step - loss: 3.3601
# Epoch 2/300
# 1/1 [==============================] - 0s 19ms/step - loss: 3.3458
# Epoch 3/300
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3316
# Epoch 4/300
# 1/1 [==============================] - 0s 13ms/step - loss: 3.3174
# Epoch 5/300
# 1/1 [==============================] - 0s 10ms/step - loss: 3.3030
# Epoch 6/300
# 1/1 [==============================] - 0s 9ms/step - loss: 3.2886
# Epoch 7/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2741
# Epoch 8/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2595
# Epoch 9/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2448
# Epoch 10/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2300
# Epoch 11/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2151
# Epoch 12/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2000
# Epoch 13/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1848
# Epoch 14/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1694
# Epoch 15/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1539
# Epoch 16/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1382
# Epoch 17/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1223
# Epoch 18/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1063
# Epoch 19/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0901
# Epoch 20/300
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0737
# Epoch 21/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0571
# Epoch 22/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0402
# Epoch 23/300
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0232
# Epoch 24/300
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0059
# Epoch 25/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9884
# Epoch 26/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9706
# Epoch 27/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9526
# Epoch 28/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9343
# Epoch 29/300
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9157
# Epoch 30/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8968
# Epoch 31/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8776
# Epoch 32/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8581
# Epoch 33/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8383
# Epoch 34/300
# 1/1 [==============================] - 0s 13ms/step - loss: 2.8181
# Epoch 35/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7976
# Epoch 36/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7767
# Epoch 37/300
# 1/1 [==============================] - 0s 14ms/step - loss: 2.7555
# Epoch 38/300
# 1/1 [==============================] - 0s 13ms/step - loss: 2.7338
# Epoch 39/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7118
# Epoch 40/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6894
# Epoch 41/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6665
# Epoch 42/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6433
# Epoch 43/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6196
# Epoch 44/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5954
# Epoch 45/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5707
# Epoch 46/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5456
# Epoch 47/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5200
# Epoch 48/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4939
# Epoch 49/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4673
# Epoch 50/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4402
# Epoch 51/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4126
# Epoch 52/300
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3844
# Epoch 53/300
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3557
# Epoch 54/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3264
# Epoch 55/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2966
# Epoch 56/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2663
# Epoch 57/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2354
# Epoch 58/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2040
# Epoch 59/300
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1720
# Epoch 60/300
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1394
# Epoch 61/300
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1064
# Epoch 62/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0728
# Epoch 63/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0387
# Epoch 64/300
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0042
# Epoch 65/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9691
# Epoch 66/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9336
# Epoch 67/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8977
# Epoch 68/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8613
# Epoch 69/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8246
# Epoch 70/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7876
# Epoch 71/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7502
# Epoch 72/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7126
# Epoch 73/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6748
# Epoch 74/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6368
# Epoch 75/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5986
# Epoch 76/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5604
# Epoch 77/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5222
# Epoch 78/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4840
# Epoch 79/300
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4459
# Epoch 80/300
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4079
# Epoch 81/300
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3701
# Epoch 82/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3326
# Epoch 83/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2954
# Epoch 84/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2585
# Epoch 85/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2221
# Epoch 86/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1862
# Epoch 87/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1508
# Epoch 88/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1160
# Epoch 89/300
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0818
# Epoch 90/300
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0482
# Epoch 91/300
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0154
# Epoch 92/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9833
# Epoch 93/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9521
# Epoch 94/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9216
# Epoch 95/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8920
# Epoch 96/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8632
# Epoch 97/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8353
# Epoch 98/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8083
# Epoch 99/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7823
# Epoch 100/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7571
# Epoch 101/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7329
# Epoch 102/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7096
# Epoch 103/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6872
# Epoch 104/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6658
# Epoch 105/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6452
# Epoch 106/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6256
# Epoch 107/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6069
# Epoch 108/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5890
# Epoch 109/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5720
# Epoch 110/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5559
# Epoch 111/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5406
# Epoch 112/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5260
# Epoch 113/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.
300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2835
# Epoch 245/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2834
# Epoch 246/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2833
# Epoch 247/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2831
# Epoch 248/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2830
# Epoch 249/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2829
# Epoch 250/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2827
# Epoch 251/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2826
# Epoch 252/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2825
# Epoch 253/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2824
# Epoch 254/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2823
# Epoch 255/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2822
# Epoch 256/300
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2821
# Epoch 257/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2819
# Epoch 258/300
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2818
# Epoch 259/300
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2817
# Epoch 260/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2816
# Epoch 261/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2816
# Epoch 262/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2815
# Epoch 263/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2814
# Epoch 264/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2813
# Epoch 265/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2812
# Epoch 266/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2811
# Epoch 267/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2810
# Epoch 268/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2809
# Epoch 269/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2809
# Epoch 270/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2808
# Epoch 271/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2807
# Epoch 272/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2806
# Epoch 273/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2806
# Epoch 274/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2805
# Epoch 275/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2804
# Epoch 276/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2803
# Epoch 277/300
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2803
# Epoch 278/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2802
# Epoch 279/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2801
# Epoch 280/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2801
# Epoch 281/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2800
# Epoch 282/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2799
# Epoch 283/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2799
# Epoch 284/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2798
# Epoch 285/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2798
# Epoch 286/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2797
# Epoch 287/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2796
# Epoch 288/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2796
# Epoch 289/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2795
# Epoch 290/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2795
# Epoch 291/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2794
# Epoch 292/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2794
# Epoch 293/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2793
# Epoch 294/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2793
# Epoch 295/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2792
# Epoch 296/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2792
# Epoch 297/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2791
# Epoch 298/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2791
# Epoch 299/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2790
# Epoch 300/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2790
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 3)]    0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, None, 3)      84          input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, None, 3)      84          lstm[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, None, 3)      84          lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 3)            84          lstm_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            12          lstm_3[0][0]
# __________________________________________________________________________________________________
# block (Block)                   (None, 3)            0           input_1[0][0]
#                                                                  dense[0][0]
# ==================================================================================================
# Total params: 348
# Trainable params: 348
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## 4.3 Model saving
model.save('../../model_saved/temporal_sequence_data_keras_model.model') 
del model  #Deleting current model
model = models.load_model('../../model_saved/temporal_sequence_data_keras_model.model',compile=False)
model.compile(optimizer="adam",loss=MSPE(name = "MSPE"))
model.predict(ds_train)
# Could also model.to_json/models.model_from_json to save structure
# Could also model.save_weights, and save ckpt in save_format = "tf"
# Out:
# INFO:tensorflow:Assets written to: ../../model_saved/temporal_sequence_data_keras_model.model/assets
# array([[1.0257219e+03, 9.3611313e+01, 2.8358908e+00],
#        [1.2651711e+03, 7.3399780e+01, 5.7663112e+00],
#        [1.3804976e+03, 1.5637344e+02, 5.3881922e+00],
#        [1.5798756e+03, 1.6701109e+02, 6.0499001e+00],
#        [1.8989783e+03, 2.7657889e+02, 6.1444297e+00],
#        [1.8051533e+03, 2.7764264e+02, 6.9006672e+00],
#        [1.5358953e+03, 4.1167703e+02, 6.9006672e+00],
#        [1.6541538e+03, 5.4252014e+02, 8.1295528e+00],
#        [1.2959574e+03, 6.3719519e+02, 8.4131422e+00],
#        [1.4528210e+03, 6.7229944e+02, 9.1693802e+00],
#        [1.2055531e+03, 7.6059192e+02, 1.0209207e+01],
#        [9.8467352e+02, 7.9144110e+02, 9.1693802e+00],
#        [7.4038652e+03, 1.2456687e+03, 2.4010540e+01],
#        [1.9776544e+03, 8.6377710e+02, 1.2288859e+00],
#        [1.2953982e+03, 1.4571327e+03, 1.4704596e+01],
#        [9.9165070e+02, 1.4020712e+03, 1.6026682e+01],
#        [1.0168446e+03, 1.5118494e+03, 1.2248386e+01],
#        [9.4106207e+02, 1.8141437e+03, 1.1639174e+01],
#        [8.7500208e+02, 1.9373000e+03, 1.6694443e+01],
#        [1.9797658e+02, 1.8762761e+03, 1.6927753e+01],
#        [4.6251123e+02, 2.2025608e+03, 2.3219706e+01],
#        [4.4457208e+02, 2.4615835e+03, 2.9378088e+01],
#        [3.8585727e+02, 2.2199402e+03, 4.3372410e+01],
#        [1.3212999e+02, 1.8085023e+03, 7.8477867e+01],
#        [3.2736615e+02, 2.4837883e+03, 4.3861633e+01],
#        [2.7441714e+02, 2.2709990e+03, 3.7729156e+01],
#        [3.0477795e+02, 2.5305242e+03, 2.3739498e+01],
#        [2.3016719e+02, 3.3329304e+03, 3.6018551e+01],
#        [3.0055472e+02, 2.6547500e+03, 3.8474361e+01],
#        [4.0332050e+02, 2.4136599e+03, 2.8651119e+01],
#        [1.4218279e+02, 2.6105808e+03, 3.4381344e+01],
#        [8.7984398e+01, 2.5231626e+03, 2.5376705e+01],
#        [8.3761147e+01, 2.4403455e+03, 3.1106930e+01],
#        [9.7838654e+01, 2.0142972e+03, 2.5376705e+01],
#        [1.0065415e+02, 1.5468405e+03, 2.4558102e+01],
#        [6.9683640e+01, 1.5440798e+03, 2.2920895e+01],
#        [3.0970509e+01, 1.5284366e+03, 2.2102291e+01],
#        [2.8155006e+01, 1.4124927e+03, 1.8009275e+01]], dtype=float32)

# %%
# 4 Model evaluation, application and saving
## 4.1 Model evaluate 
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.title('Training '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric])
    plt.show()

plot_metric(history,"loss")

# %%
##4.2 Model Application
#This "dfresult" is used to record the current and predicted data
dfresult = dfdiff[["confirmed_num","cured_num","dead_num"]].copy()
dfresult.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-152cb4d6fcf0> in <module>
#       1 ##4.2 Model Application
#       2 #This "dfresult" is used to record the current and predicted data
# ----> 3 dfresult = dfdiff[["confirmed_num","cured_num","dead_num"]].copy()
#       4 dfresult.tail()
#
# NameError: name 'dfdiff' is not defined

# %%
#Predicting the daily increment of the new confirmed cases of the next 100 days; add this result into dfresult
for i in range(100):
    arr_predict = model.predict(tf.constant(tf.expand_dims(dfresult.values[-38:,:],axis = 0)))

    dfpredict = pd.DataFrame(tf.cast(tf.floor(arr_predict),tf.float32).numpy(),
                columns = dfresult.columns)
    dfresult = dfresult.append(dfpredict,ignore_index=True)

# %%
dfresult.query("confirmed_num==0").head()

# From Day 55 the daily increment of the new confirmed cases reduced to zero. Since Day 45 is corresponding to March 10, the daily increment of the news confirmed cases will reduce to 0 in Manch 20.
# Note: this prediction is TOO optimistic

# %%
dfresult.query("cured_num==0").head()

# The daily increment of the discharged (cured) cases will reduce to 0 in Day 164, which is about 4 months after March 10 (i.e. July 10) all the patients will be discharged.
# Note: this prediction is TOO pessimistic and problematic: the total sum of the daily increment of discharged cases is larger than cumulated confirmed cases.

# %%
dfresult.query("dead_num==0").head()

# The daily increment of the deceased will be reduced to 0 from Day 60, which is March 25, 2020
# Note: This prediction is relatively reasonable.
