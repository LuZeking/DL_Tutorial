# %%
"""visualization of filters and maps, refer to this very good resource 
    https://debuggercafe.com/visualizing-filters-and-feature-maps-in-convolutional-neural-networks-using-pytorch/
    
    can also see in the forum 
    https://discuss.pytorch.org/t/visualize-feature-map/29597
    """

# %%
import torch 
import os 
import torchvision

from torch.utils.data import Dataset, DataLoader
from utils.dataset import load_Minst

from backbone.cnn import SimpleModel
from torchvision import models, transforms

from torch import nn
from torch import optim
from tqdm import tqdm
from datetime import datetime

# %%
# 1&2 Dataset and Dataloader
train_dataset, test_dataset = load_Minst(dataset_path = "/home/hpczeji1/hpc-work/Codebase/Datasets/mnist_data")
train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=10000,
                          shuffle=True)

# %%
# 3 Model 
model = models.resnet50(pretrained=True)
print(model)

model_weights = [] # we will save the conv layer weights in this list
conv_layers = [] # we will save the 49 conv layers in this list

# get all the model children as list
model_children = list(model.children())

#  4&5 load pretrained model, no need to do optimzer setting and training
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /home/hpczeji1/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## visualize filters
# - model_weights.append(model_children[i].weight) to get weights

# %%
# Out:
# [Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
#  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  ReLU(inplace=True),
#  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False),
#  Sequential(
#    (0): Bottleneck(
#      (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#      (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (downsample): Sequential(
#        (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# ## visualize activation maps
# - get all conv_layers: conv_layers.append(model_children[i])
# - Passing the Input Image Through Each Convolutional Layer
